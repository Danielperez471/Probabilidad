# %% [markdown]
# ##EJEMPLO 3: Histogramas de 2 grupos
#
# 1. en este ejemplo generamos 100 numeros aleatorios reales que representa la produccion diaria de 100 telares (medidas en metros).
# 2. generar otra lista con la produccion de 100 telares para una segunda fabrica.
# 3. con estas listas de valores se pretende determinar las medidas de tendencia central, es decir, la media, la moda, la mediana, la desviacion estandar.
# 4. graficar un histograma para cada fabrica.

# %%
from statistics import *

# %%
#libreria para generar numeros aleatorios
import random

# %%
fabrica1=[]
for i in range (100):
  numero_aleatorio= round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [72.92, 87.55, 68.7, 82.79, 90.43, 61.73, 57.18, 64.77, 95.43, 51.02, 68.88, 60.35, 81.15, 63.12, 76.37, 81.33, 54.38, 59.25, 75.93, 76.68, 72.94, 52.13, 77.82, 63.31, 52.2, 64.23, 69.24, 65.34, 86.16, 69.04, 87.45, 96.63, 62.22, 71.81, 51.74, 92.36, 74.45, 76.78, 84.71, 62.0, 65.47, 89.93, 97.48, 66.03, 95.5, 63.4, 67.78, 51.5, 71.07, 67.63, 80.73, 72.67, 71.24, 71.26, 64.97, 95.85, 75.26, 79.71, 71.69, 61.92, 72.9, 98.68, 63.6, 93.51, 83.69, 72.23, 57.26, 70.92, 63.54, 80.94, 85.98, 59.05, 91.47, 63.47, 58.12, 91.52, 56.56, 68.69, 72.49, 55.41, 51.61, 87.61, 92.55, 91.88, 55.1, 90.66, 93.8, 73.09, 53.27, 97.23, 74.92, 87.85, 56.87, 89.48, 77.3, 60.4, 97.91, 56.41, 55.46, 83.91]

# %%
fabrica2=[]
for i in range (100):
  numero_aleatorio2= round(random.uniform(50,100),2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [52.13, 54.29, 81.24, 94.36, 92.37, 67.53, 83.84, 54.25, 86.45, 80.7, 95.26, 88.27, 87.1, 83.76, 69.65, 73.34, 56.08, 85.52, 92.4, 85.94, 90.5, 70.69, 87.07, 64.3, 50.46, 88.99, 74.71, 93.12, 95.14, 82.04, 90.32, 71.56, 78.87, 59.59, 71.75, 91.93, 96.4, 69.61, 68.64, 77.67, 95.72, 53.98, 55.16, 61.33, 74.68, 58.06, 82.97, 72.25, 84.85, 62.32, 62.72, 53.57, 62.8, 54.53, 98.57, 88.36, 74.25, 93.89, 58.9, 72.49, 76.5, 99.77, 64.13, 76.98, 82.28, 92.36, 98.74, 82.25, 59.49, 57.1, 74.79, 72.76, 55.12, 97.92, 65.78, 55.04, 54.53, 82.3, 55.11, 84.86, 84.59, 57.55, 80.56, 62.69, 81.15, 51.9, 80.2, 51.38, 93.37, 79.31, 60.18, 61.81, 58.14, 52.46, 63.95, 69.32, 96.5, 80.19, 74.2, 75.46]

# %%
#libreria de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2')

# %%
media=mean(fabrica1)
moda = mode(fabrica1)
mediana = median(fabrica1)

print ("valores de la fabrica 1")
print ("la media es: ",media)
print("la mediana es: ",mediana)
print("la moda es: ",moda)
# Out:
# valores de la fabrica 1
# la media es:  73.3095
# la mediana es:  72.02000000000001
# la moda es:  72.92

# %%
media=mean(fabrica2)
moda = mode(fabrica2)
mediana = median(fabrica2)

print ("valores de la fabrica 2")
print ("la media es: ",media)
print("la mediana es: ",mediana)
print("la moda es: ",moda)
# Out:
# valores de la fabrica 2
# la media es:  74.6196
# la mediana es:  74.75
# la moda es:  54.53

# %%
#generar 2 subplot de 1 renglon por 2 columnas para desplegar los 2 histogramas,
# una al lado de la otra
fig, (ax1, ax2)=plt.subplots(nrows=1,ncols=2)

# %%
#generar 2 subplot de 1 renglon por 2 columnas para desplegar los 2 histogramas,
# una al lado de la otra
fig, (ax1, ax2)=plt.subplots(nrows=1,ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
#valor minimo, maximo, rango de la fabrica1
media1=mean(fabrica1)
moda1 = mode(fabrica1)
mediana1 = median(fabrica1)

# %%
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor='black')
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label="media")
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label="mediana")
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label="moda")
plt.xlabel=('valor')
plt.ylabel=('Frecuencia')
plt.title("produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
#valor minimo, maximo, rango de la fabric2
media2=mean(fabrica2)
moda2 = mode(fabrica2)
mediana2 = median(fabrica2)

# %%
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor='black')
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label="media")
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label="mediana")
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label="moda")
plt.xlabel=('valor')
plt.ylabel=('Frecuencia')
plt.title("produccion diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# ##MAXIMO, MINIMO Y RANGO

# %%
maximo= max(fabrica1)
minimo = min(fabrica1)
rango= maximo - minimo
media= mean (fabrica1)
mediana =median(fabrica1)
moda= mode(fabrica1)

print( "Estadistica descriptiva de la fabrica 1\n", "media= ",media,
      "\n mediana= ",mediana," \n moda= ",moda, "\n maximo=",maximo,
       "\n minimo= ",minimo, "\n rango= ",rango)
# Out:
# Estadistica descriptiva de la fabrica 1
#  media=  73.3095
#  mediana=  72.02000000000001
#  moda=  72.92
#  maximo= 98.68
#  minimo=  51.02
#  rango=  47.660000000000004

# %%
maximo2= max(fabrica2)
minimo2 = min(fabrica2)
rango2= maximo - minimo
media2= mean (fabrica2)
mediana2 =median(fabrica2)
moda2= mode(fabrica2)

print( "Estadistica descriptiva de la fabrica 2\n", "media= ",media2,
      "\n mediana= ",mediana2," \n moda= ",moda2, "\n maximo=",maximo2,
       "\n minimo= ",minimo2, "\n rango= ",rango2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  media=  74.6196
#  mediana=  74.75
#  moda=  54.53
#  maximo= 99.77
#  minimo=  50.46
#  rango=  47.660000000000004

# %% [markdown]
# ## DISPERSION DE LOS DATOS

# %%
de_fabrica1 = stdev(fabrica1)
print ("la desviacion estandar de la fabrica 1 es: ",de_fabrica1)
# Out:
# la desviacion estandar de la fabrica 1 es:  13.7188940254974

# %%
de_fabrica2 = stdev(fabrica2)
print ("la desviacion estandar de la fabrica 2 es: ",de_fabrica2)
# Out:
# la desviacion estandar de la fabrica 2 es:  14.464209113979557

# %%
plt.figure (figsize=(10,8))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor='black')
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f"media={media1:.2f}")
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f"mediana={mediana1:.2f}")
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f"moda={moda:.2f} ")

plt.axvline(media-de_fabrica1, color='black',
            linestyle='dashed', linewidth=2, label=f"desv. Estandar={de_fabrica1:.2f}")
plt.axvline(media+de_fabrica1, color='black',
            linestyle='dashed', linewidth=2)

plt.xlabel=('valor')
plt.ylabel=('Frecuencia')
plt.title("produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure (figsize=(10,8))
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor='black')
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f"media={media2:.2f}")
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f"mediana={mediana2:.2f}")
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f"moda={moda2:.2f} ")

plt.axvline(media-de_fabrica2, color='black',
            linestyle='dashed', linewidth=2, label=f"desv. Estandar={de_fabrica2:.2f}")
plt.axvline(media+de_fabrica2, color='black',
            linestyle='dashed', linewidth=2)

plt.xlabel=('valor')
plt.ylabel=('Frecuencia')
plt.title("produccion diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# ##Tablas de frecuencias

# %%
#generamos una lista vacia que representa la edad de un grupo de personas
edades =[]
for i in range (100):
  n_aleatorio = random.randint(18,70)
  edades.append(n_aleatorio)
print (edades)
# Out:
# [61, 43, 31, 45, 23, 57, 22, 43, 33, 32, 57, 49, 32, 30, 21, 65, 22, 49, 51, 23, 38, 70, 68, 31, 62, 55, 24, 43, 41, 44, 52, 32, 18, 54, 45, 34, 65, 56, 36, 67, 47, 59, 34, 33, 50, 62, 54, 44, 35, 49, 20, 22, 22, 35, 63, 45, 61, 31, 62, 37, 67, 56, 52, 50, 43, 26, 18, 28, 28, 70, 61, 63, 44, 67, 41, 56, 18, 66, 31, 56, 39, 59, 37, 23, 40, 24, 25, 18, 38, 56, 22, 54, 59, 38, 47, 28, 40, 34, 30, 46]

# %%
import pandas as pd

# %%
df_edades=pd.DataFrame(edades, columns=["Edad"])
df_edades
# Out:
#     Edad
# 0     61
# 1     43
# 2     31
# 3     45
# 4     23
# ..   ...
# 95    28
# 96    40
# 97    34
# 98    30
# 99    46
#
# [100 rows x 1 columns]

# %%
#calcular la tabla de distribucion de frecuencias
#(frec. relativa, frec.porcentual, frec. acumulada)
t_frec=df_edades["Edad"].value_counts().reset_index()
t_frec.columns=["Edad","Frecuencia"]
t_frec=t_frec.sort_values(by="Edad")
t_frec["frec. relativa"]=t_frec["Frecuencia"]/100
t_frec["frec. porcentual"]= t_frec["Frecuencia"]/100*100
t_frec["frec. acumulada"]=t_frec["Frecuencia"].cumsum()
t_frec
# Out:
#     Edad  Frecuencia  frec. relativa  frec. porcentual  frec. acumulada
# 3     18           4            0.04               4.0                4
# 37    20           1            0.01               1.0                5
# 39    21           1            0.01               1.0                6
# 0     22           5            0.05               5.0               11
# 17    23           3            0.03               3.0               14
# 28    24           2            0.02               2.0               16
# 35    25           1            0.01               1.0               17
# 32    26           1            0.01               1.0               18
# 7     28           3            0.03               3.0               21
# 25    30           2            0.02               2.0               23
# 2     31           4            0.04               4.0               27
# 14    32           3            0.03               3.0               30
# 23    33           2            0.02               2.0               32
# 10    34           3            0.03               3.0               35
# 19    35           2            0.02               2.0               37
# 38    36           1            0.01               1.0               38
# 31    37           2            0.02               2.0               40
# 6     38           3            0.03               3.0               43
# 34    39           1            0.01               1.0               44
# 29    40           2            0.02               2.0               46
# 27    41           2            0.02               2.0               48
# 4     43           4            0.04               4.0               52
# 13    44           3            0.03               3.0               55
# 16    45           3            0.03               3.0               58
# 42    46           1            0.01               1.0               59
# 21    47           2            0.02               2.0               61
# 15    49           3            0.03               3.0               64
# 20    50           2            0.02               2.0               66
# 36    51           1            0.01               1.0               67
# 26    52           2            0.02               2.0               69
# 11    54           3            0.03               3.0               72
# 40    55           1            0.01               1.0               73
# 1     56           5            0.05               5.0               78
# 24    57           2            0.02               2.0               80
# 8     59           3            0.03               3.0               83
# 5     61           3            0.03               3.0               86
# 12    62           3            0.03               3.0               89
# 18    63           2            0.02               2.0               91
# 30    65           2            0.02               2.0               93
# 33    66           1            0.01               1.0               94
# 9     67           3            0.03               3.0               97
# 41    68           1            0.01               1.0               98
# 22    70           2            0.02               2.0              100

# %% [markdown]
# ##Regla de Sturges
# 1. es una regla que sirve para calcular el numero de clases o intervalos idoneo, en los que se debe dividir un conjunto de datos
#
# $
# c=1+log_2(N)
# $

# %%
#libreria de funciones matematicas
import math

# %%
df_edades_sturges= pd.DataFrame({"Edad":edades})
df_edades_sturges
# Out:
#     Edad
# 0     61
# 1     43
# 2     31
# 3     45
# 4     23
# ..   ...
# 95    28
# 96    40
# 97    34
# 98    30
# 99    46
#
# [100 rows x 1 columns]

# %%
plt.hist(edades, alpha=0.5, rwidth=0.85)
plt.title("Histograma de edades basado en valores estandar de matplotlib" )
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en valores estandar de matplotlib')

# %%
#calcular el numero de intervalos usando la regla de Sturges
n=len(edades)
k=int(1+math.log2(n))
print("valor de n=",n,"\nk o numero de intervalos= ",k)
# Out:
# valor de n= 100
# k o numero de intervalos=  7

# %%
#creamos la tabla de frecuencias con los intervalos
t_frec_sturges=pd.cut(df_edades_sturges["Edad"],bins=k).value_counts().reset_index()
t_frec_sturges.columns=["clase","Frecuencia"]
t_frec_sturges=t_frec_sturges.sort_values(by="clase")
t_frec_sturges["frec. relativa"]=t_frec_sturges["Frecuencia"]/n
t_frec_sturges["frec. porcentual"]= t_frec_sturges["Frecuencia"]/n*100
t_frec_sturges["frec. acumulada"]=t_frec_sturges["Frecuencia"].cumsum()
t_frec_sturges
# Out:
#               clase  Frecuencia  frec. relativa  frec. porcentual  \
# 0  (17.948, 25.429]          17            0.17              17.0
# 4  (25.429, 32.857]          13            0.13              13.0
# 1  (32.857, 40.286]          16            0.16              16.0
# 3  (40.286, 47.714]          15            0.15              15.0
# 5  (47.714, 55.143]          12            0.12              12.0
# 2  (55.143, 62.571]          16            0.16              16.0
# 6    (62.571, 70.0]          11            0.11              11.0
#
#    frec. acumulada
# 0               17
# 4               30
# 1               46
# 3               61
# 5               73
# 2               89
# 6              100

# %%
plt.hist(df_edades_sturges["Edad"],bins=k, rwidth=0.85)
plt.title("Histograma de edades basado en la regla de Sturges")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la regla de Sturges')

# %% [markdown]
# ##DIAGRAMA DE CAJAS Y BIGOTES

# %%
plt.boxplot(fabrica1)
plt.title("Produccion de la fabrica 1")
plt.show()

# %%
plt.boxplot(fabrica2)
plt.title("Produccion de la fabrica 2")
plt.show()

# %% [markdown]
# ##Comparamos la produccion de la fabrica 1 y la fabrica 2 con un diagrama de cajas y bigotes

# %%
fig,(ax1, ax2) =plt.subplots(nrows=1, ncols=2,figsize=(9,5))
ax1.boxplot( fabrica1, vert=True, patch_artist=True)
ax1.set_title("Produccion de la fabrica 1")
ax2.boxplot( fabrica2, vert=True, patch_artist=True)
ax2.set_title("Produccion de la fabrica 2")
plt.show()

# %%
fabrica2.append(150)
print(fabrica2)
plt.boxplot(fabrica2)
plt.title("Produccion de la fabrica 2")
plt.show()
# Out:
# [52.13, 54.29, 81.24, 94.36, 92.37, 67.53, 83.84, 54.25, 86.45, 80.7, 95.26, 88.27, 87.1, 83.76, 69.65, 73.34, 56.08, 85.52, 92.4, 85.94, 90.5, 70.69, 87.07, 64.3, 50.46, 88.99, 74.71, 93.12, 95.14, 82.04, 90.32, 71.56, 78.87, 59.59, 71.75, 91.93, 96.4, 69.61, 68.64, 77.67, 95.72, 53.98, 55.16, 61.33, 74.68, 58.06, 82.97, 72.25, 84.85, 62.32, 62.72, 53.57, 62.8, 54.53, 98.57, 88.36, 74.25, 93.89, 58.9, 72.49, 76.5, 99.77, 64.13, 76.98, 82.28, 92.36, 98.74, 82.25, 59.49, 57.1, 74.79, 72.76, 55.12, 97.92, 65.78, 55.04, 54.53, 82.3, 55.11, 84.86, 84.59, 57.55, 80.56, 62.69, 81.15, 51.9, 80.2, 51.38, 93.37, 79.31, 60.18, 61.81, 58.14, 52.46, 63.95, 69.32, 96.5, 80.19, 74.2, 75.46, 150, 150]
